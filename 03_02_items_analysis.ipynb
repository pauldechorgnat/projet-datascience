# %% [markdown]
# <img src="https://datascientest.fr/train/assets/logo_datascientest.png" style="height:150px">
#
# <hr style="border-width:2px;border-color:#75DFC1">
# <center><h1>Projet Data Science</h1></center>
# <center><h2>Analyse du jeu de données produits</h2></center>
# <hr style="border-width:2px;border-color:#75DFC1">
#
# <blockquote>
# Dans cette leçon, nous allons étudier le jeu de données que nous avons construit plus tôt. Nous voulons voir quels sont les comportements des visiteurs vis-à-vis des produits sur le site internet.
# <br>Nous n'allons pas faire toute l'étude du jeu de données mais donner des pistes sur les informations à montrer.
# <ul>
# <li>regarder la répartition des achats et des différents événements</li>
# <li>regarder quels sont les produits les plus achetés et essayer de déterminer </li>
#     <li>déterminer si il y a des tendances saisonnières (heure, fin de semaine, ...)</li>
#     <li>voir combien de vues pour un achats par produits, ...</li>
# <li>...</li>
# </blockquote>

# %%
# Insérer le code ici

# %%
# Insérer le code ici

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('item_data.csv', index_col=0)
df.head()
# Out:
#         nb_unique_transactions  nb_view_events  nb_addtocart_events  \
# itemid
# 3                          1.0             2.0                  0.0
# 4                          1.0             3.0                  0.0
# 6                          1.0            29.0                  0.0
# 9                          1.0             2.0                  0.0
# 15                         2.0            18.0                  3.0
#
#         nb_transaction_events             min_datetime  \
# itemid
# 3                           0  2015-08-18 20:30:40.493
# 4                           0  2015-06-30 09:03:11.545
# 6                           0  2015-05-06 22:33:13.122
# 9                           0  2015-05-14 00:53:14.505
# 15                          1  2015-05-25 23:50:41.181
#
#                    max_datetime  nb_view_unique_products  \
# itemid
# 3       2015-08-31 16:39:02.792                        2
# 4       2015-09-16 01:22:44.099                        3
# ...
